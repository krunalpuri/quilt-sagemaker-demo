# %% [markdown]
# # sagemaker-demo-notebook
#
# This notebook is an interactive companion to the article. In it we will do the following:
#
# * Build a machine learning model image and store it on ECR, Amazon's container registry service.
# * Train a machine learning model based on the image we just pushed.
# * Deploy that model to a web endpoint.
# * Deploy an arbitrary Sagemaker-complaint model artifact to a web endpoint.
# * Perform a batch classification job using a SageMaker-compliant model artifact (unfinished?).
#
# You may run this notebook either locally or in an AWS SageMaker instance.
#
# If you are running locally, make sure that the account you are running this notebook under has all of the necessary permissions: `S3ReadOnlyAccess`, `SagemakerFullAccess`, `iam:GetRole`, and `ECRFullAccess`.
#
# If you are running on AWS SageMaker, make sure that the role you pass to the notebook instance has all of these permissions available. Note that the default SageMaker execution context is **not** enough; it has the first permissions in the list above but not the latter two. You need to attach those permissions to the instance yourself.
#
#
# ## Getting the code
#
# We start by downloading the code from [its repository](https://github.com/ResidentMario/quilt-sagemaker-demo) on GitHub.

# %%
# !rm -rf quilt-sagemaker-demo > /dev/null 2>&1
# !git clone https://github.com/ResidentMario/quilt-sagemaker-demo
# Out:
# Cloning into 'quilt-sagemaker-demo'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 108 (delta 58), reused 82 (delta 32), pack-reused 0
# Receiving objects: 100% (108/108), 861.00 KiB | 35.87 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
# %ls quilt-sagemaker-demo
# Out:
# Dockerfile                     fashion-mnist_train.csv
# README.md                      health-check-data.csv
# app.py                         requirements.txt
# build.ipynb                    run.sh*
# clf.h5                         sagemaker-demo-notebook.ipynb

# %% [markdown]
# The files are:
# * `build.ipynb` &mdash; A Jupyter notebook that walks through building and training a model for classifying clothing that is based on the Fashion MNIST dataset.
# * `app.py` &mdash; A simple `flask` app that serves a SageMaker-compliant model-as-an-app.
# * `health-check-data.csv` &mdash; A small sample dataset used to ping the web service for health checks.
# * `Dockerfile` &mdash; A Dockerfile that builds an image suitable for distribution on SageMaker.
# * `run.sh` &mdash; The image runtime entrypoint.
# * `requirements.txt` &mdash; A list of dependencies necesssary for building or running the model (locally or remotely).
#
# ...and this notebook.

# %% [markdown]
# ## Pusing the container
#
# The following shell script, inlined in this notebook, builds the Docker image we've imported and stores it in ECR.

# %%
# %%sh
#
# # construct the ECR name.
# account=$(aws sts get-caller-identity --query Account --output text)
# region=$(aws configure get region)
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/quiltdata/sagemaker-demo:latest"
#
# echo "DONE1"
# # If the repository doesn't exist in ECR, create it.
# # The pipe trick redirects stderr to stdout and passes it /dev/null.
# # It's just there to silence the error.
# aws ecr describe-repositories --repository-names "quiltdata/sagemaker-demo" > /dev/null 2>&1
#
# echo "DONE2"
# # Check the error code, if it's non-zero then know we threw an error and no repo exists
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "quiltdata/sagemaker-demo" > /dev/null
# fi
#
#
# echo "DONE3"
# # Get the login command from ECR and execute it directly
# $(aws ecr get-login --region ${region} --no-include-email)
#
# echo "DONE4"
# # Build the docker image, tag it with the full name, and push it to ECR
# docker build  -t "quiltdata/sagemaker-demo" quilt-sagemaker-demo/
# docker tag "quiltdata/sagemaker-demo" ${fullname}
# echo "DONE5"
# docker push ${fullname}
# Out:
# DONE1
# DONE2
# DONE3
# Login Succeeded
# DONE4
# Sending build context to Docker daemon  1.358GB
# Step 1/14 : FROM python:3.6
#  ---> 1c515a624542
# Step 2/14 : RUN ["mkdir", "app"]
#  ---> Using cache
#  ---> 051fdec606bc
# Step 3/14 : WORKDIR "app"
#  ---> Using cache
#  ---> 1050e38336a5
# Step 4/14 : COPY "requirements.txt" .
#  ---> fcf01e8fb82f
# Step 5/14 : RUN ["pip", "install", "-r", "requirements.txt"]
#  ---> Running in a15439a13430
# Collecting git+https://github.com/quiltdata/t4.git#subdirectory=api/python (from -r requirements.txt (line 3))
#   Cloning https://github.com/quiltdata/t4.git to /tmp/pip-req-build-mtypd_ju
#   Running command git clone -q https://github.com/quiltdata/t4.git /tmp/pip-req-build-mtypd_ju
# Collecting numpy (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/75/92/57179ed45307ec6179e344231c47da7f3f3da9e2eee5c8ab506bd279ce4e/numpy-1.17.1-cp36-cp36m-manylinux1_x86_64.whl (20.4MB)
# Collecting pandas (from -r requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/73/9b/52e228545d14f14bb2a1622e225f38463c8726645165e1cb7dde95bfe6d4/pandas-0.25.1-cp36-cp36m-manylinux1_x86_64.whl (10.5MB)
# Collecting flask (from -r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/9b/93/628509b8d5dc749656a9641f4caf13540e2cdec85276964ff8f43bbb1d3b/Flask-1.1.1-py2.py3-none-any.whl (94kB)
# Collecting tensorflow (from -r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
# Collecting keras (from -r requirements.txt (line 6))
#   Downloading https://files.pythonhosted.org/packages/f8/ba/2d058dcf1b85b9c212cc58264c98a4a7dd92c989b798823cc5690d062bb2/Keras-2.2.5-py2.py3-none-any.whl (336kB)
# Collecting jupyter (from -r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# Collecting seaborn (from -r requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/a8/76/220ba4420459d9c4c9c9587c6ce607bf56c25b3d3d2de62056efe482dadc/seaborn-0.9.0-py3-none-any.whl (208kB)
# Collecting scikit-learn (from -r requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/a0/c5/d2238762d780dde84a20b8c761f563fe882b88c5a5fb03c056547c442a19/scikit_learn-0.21.3-cp36-cp36m-manylinux1_x86_64.whl (6.7MB)
# Collecting awscli (from -r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/97/72/bafa0c932416fb91c87f172cd4b0fdff5be32e4d01a3c89c8ae03549d7c3/awscli-1.16.229-py2.py3-none-any.whl (2.0MB)
# Collecting requests==2.20.0 (from -r requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/f1/ca/10332a30cb25b627192b4ea272c351bce3ca1091e541245cccbace6051d8/requests-2.20.0-py2.py3-none-any.whl (60kB)
# Collecting sagemaker (from -r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/03/ac/d6a8544f7e756c2b15c57aa53212421d7afbea060c9370098790b9572c81/sagemaker-1.38.4.tar.gz (219kB)
# Collecting boto3 (from -r requirements.txt (line 13))
#   Downloading https://files.pythonhosted.org/packages/c7/b1/34db0f2db2d4f54e278ae32cb563aa4e278b1dd62a55672d691a3ceab4e9/boto3-1.9.219-py2.py3-none-any.whl (128kB)
# Collecting botocore (from -r requirements.txt (line 14))
#   Downloading https://files.pythonhosted.org/packages/0f/8a/bfb0629723e49fc1519f39f3fa049ab245092346f27d09ef51f517d19c22/botocore-1.12.219-py2.py3-none-any.whl (5.7MB)
# Collecting appdirs>=1.4.0 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/56/eb/810e700ed1349edde4cbdc1b2a21e28cdf115f9faf263f6bbf8447c1abf3/appdirs-1.4.3-py2.py3-none-any.whl
# Collecting aws-requests-auth>=0.4.2 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/a7/ba/e1601d0508b4150f8fe503f681079a7c9a17f7aa44e0d5cc42b9e3abdb8e/aws-requests-auth-0.4.2.tar.gz
# Collecting elasticsearch~=6.3.1 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/b1/f1/89735ebb863767516d55cee2cfdd5e2883ff1db903be3ba1fe15a1725adc/elasticsearch-6.3.1-py2.py3-none-any.whl (119kB)
# Collecting future>=0.16.0 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/90/52/e20466b85000a181e1e144fd8305caf2cf475e2f9674e797b222f8105f5f/future-0.17.1.tar.gz (829kB)
# Collecting jsonlines==1.2.0 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/4f/9a/ab96291470e305504aa4b7a2e0ec132e930da89eb3ca7a82fbe03167c131/jsonlines-1.2.0-py2.py3-none-any.whl
# Collecting packaging>=16.8 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/ec/22/630ac83e8f8a9566c4f88038447ed9e16e6f10582767a01f31c769d9a71e/packaging-19.1-py2.py3-none-any.whl
# Collecting pyarrow>=0.9.0 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/6f/df/33d8d6b682750d16baa9f45db825f33e0e0feb479fac1da9758f7ac8fd4b/pyarrow-0.14.1-cp36-cp36m-manylinux2010_x86_64.whl (58.1MB)
# Collecting ruamel.yaml<=0.15.70 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/6b/25/7982d70b5b3c66885d455cc72c82c7d46081bb955ac7a4fba1a1fbc9de85/ruamel.yaml-0.15.70-cp36-cp36m-manylinux1_x86_64.whl (646kB)
# Collecting six>=1.10.0 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting tqdm>=4.26.0 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/dc/88/d3213e2f3492daf09d8b41631ad6899f56db17ce83ea9c8a579902bafe5e/tqdm-4.35.0-py2.py3-none-any.whl (50kB)
# Collecting urllib3<1.25,>=1.21.1 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/01/11/525b02e4acc0c747de8b6ccdab376331597c569c42ea66ab0a1dbd36eca2/urllib3-1.24.3-py2.py3-none-any.whl (118kB)
# Collecting humanize (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/8c/e0/e512e4ac6d091fc990bbe13f9e0378f34cf6eecd1c6c268c9e598dcf5bb9/humanize-0.5.1.tar.gz
# Collecting ipywidgets>=0.6.0 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/56/a0/dbcf5881bb2f51e8db678211907f16ea0a182b232c591a6d6f276985ca95/ipywidgets-7.5.1-py2.py3-none-any.whl (121kB)
# Collecting xattr>=0.9.6 (from t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/60/80/a1f35bfd3c7ffb78791b2a6a15c233584a102a20547fd96d48933ec453e7/xattr-0.9.6.tar.gz
# Collecting python-dateutil>=2.6.1 (from pandas->-r requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl (226kB)
# Collecting pytz>=2017.2 (from pandas->-r requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/87/76/46d697698a143e05f77bec5a526bf4e56a0be61d63425b68f4ba553b51f2/pytz-2019.2-py2.py3-none-any.whl (508kB)
# Collecting click>=5.1 (from flask->-r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl (81kB)
# Collecting itsdangerous>=0.24 (from flask->-r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Collecting Werkzeug>=0.15 (from flask->-r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/d1/ab/d3bed6b92042622d24decc7aadc8877badf18aeca1571045840ad4956d3f/Werkzeug-0.15.5-py2.py3-none-any.whl (328kB)
# Collecting Jinja2>=2.10.1 (from flask->-r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/1d/e7/fd8b501e7a6dfe492a433deb7b9d833d39ca74916fa8bc63dd1a4947a671/Jinja2-2.10.1-py2.py3-none-any.whl (124kB)
# Collecting keras-preprocessing>=1.0.5 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
# Collecting keras-applications>=1.0.6 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
# Collecting protobuf>=3.6.1 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/eb/f4/a27952733796330cd17c17ea1f974459f5fefbbad119c0f296a6d807fec3/protobuf-3.9.1-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
# Collecting astor>=0.6.0 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/d1/4f/950dfae467b384fc96bc6469de25d832534f6b4441033c39f914efd13418/astor-0.8.0-py2.py3-none-any.whl
# Collecting wrapt>=1.11.1 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Collecting termcolor>=1.1.0 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting google-pasta>=0.1.6 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/d0/33/376510eb8d6246f3c30545f416b2263eee461e40940c2a4413c711bdf62d/google_pasta-0.1.7-py3-none-any.whl (52kB)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/site-packages (from tensorflow->-r requirements.txt (line 5)) (0.33.6)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
# Collecting grpcio>=1.8.6 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/30/31/6397193572c081e0fd1fec86a7a6b7ac497c27226281e7cb32f8c3705069/grpcio-1.23.0-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
# Collecting absl-py>=0.7.0 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/3c/0d/7cbf64cac3f93617a2b6b079c0182e4a83a3e7a8964d3b0cc3d9758ba002/absl-py-0.8.0.tar.gz (102kB)
# Collecting tensorboard<1.15.0,>=1.14.0 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
# Collecting gast>=0.2.0 (from tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting scipy>=0.14 (from keras->-r requirements.txt (line 6))
#   Downloading https://files.pythonhosted.org/packages/29/50/a552a5aff252ae915f522e44642bb49a7b7b31677f9580cfd11bcc869976/scipy-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (25.2MB)
# Collecting pyyaml (from keras->-r requirements.txt (line 6))
#   Downloading https://files.pythonhosted.org/packages/e3/e8/b3212641ee2718d556df0f23f78de8303f068fe29cdaa7a91018849582fe/PyYAML-5.1.2.tar.gz (265kB)
# Collecting h5py (from keras->-r requirements.txt (line 6))
#   Downloading https://files.pythonhosted.org/packages/30/99/d7d4fbf2d02bb30fb76179911a250074b55b852d34e98dd452a9f394ac06/h5py-2.9.0-cp36-cp36m-manylinux1_x86_64.whl (2.8MB)
# Collecting qtconsole (from jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/21/a0/37a7b61eeac6d02cdabc45a60659297e3017f6ff7f2ca6bdec629aa248dd/qtconsole-4.5.4-py2.py3-none-any.whl (120kB)
# Collecting notebook (from jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/f3/a1/1e07cedcb554408fefe4a7d32b2a041c86517167aec6ca8251c808ef6c1e/notebook-6.0.1-py3-none-any.whl (9.0MB)
# Collecting jupyter-console (from jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/cb/ee/6374ae8c21b7d0847f9c3722dcdfac986b8e54fa9ad9ea66e1eb6320d2b8/jupyter_console-6.0.0-py2.py3-none-any.whl
# Collecting ipykernel (from jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/d4/16/43f51f65a8a08addf04f909a0938b06ba1ee1708b398a9282474531bd893/ipykernel-5.1.2-py3-none-any.whl (116kB)
# Collecting nbconvert (from jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/f9/df/4505c0a7fea624cac461d0f41051f33456ae656753f65cee8c2f43121cb2/nbconvert-5.6.0-py2.py3-none-any.whl (453kB)
# Collecting matplotlib>=1.4.3 (from seaborn->-r requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/57/4f/dd381ecf6c6ab9bcdaa8ea912e866dedc6e696756156d8ecc087e20817e2/matplotlib-3.1.1-cp36-cp36m-manylinux1_x86_64.whl (13.1MB)
# Collecting joblib>=0.11 (from scikit-learn->-r requirements.txt (line 9))
#   Downloading https://files.pythonhosted.org/packages/cd/c1/50a758e8247561e58cb87305b1e90b171b8c767b15b12a1734001f41d356/joblib-0.13.2-py2.py3-none-any.whl (278kB)
# Collecting s3transfer<0.3.0,>=0.2.0 (from awscli->-r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/16/8a/1fc3dba0c4923c2a76e1ff0d52b305c44606da63f718d14d3231e21c51b0/s3transfer-0.2.1-py2.py3-none-any.whl (70kB)
# Collecting docutils<0.16,>=0.10 (from awscli->-r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/22/cd/a6aa959dca619918ccb55023b4cb151949c64d4d5d55b3f4ffd7eee0c6e8/docutils-0.15.2-py3-none-any.whl (547kB)
# Collecting rsa<=3.5.0,>=3.1.2 (from awscli->-r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/e1/ae/baedc9cb175552e95f3395c43055a6a5e125ae4d48a1d7a924baca83e92e/rsa-3.4.2-py2.py3-none-any.whl (46kB)
# Collecting colorama<=0.3.9,>=0.2.5 (from awscli->-r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/db/c8/7dcf9dbcb22429512708fe3a547f8b6101c0d02137acbd892505aee57adf/colorama-0.3.9-py2.py3-none-any.whl
# Collecting certifi>=2017.4.17 (from requests==2.20.0->-r requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/69/1b/b853c7a9d4f6a6d00749e94eb6f3a041e342a885b87340b79c1ef73e3a78/certifi-2019.6.16-py2.py3-none-any.whl (157kB)
# Collecting chardet<3.1.0,>=3.0.2 (from requests==2.20.0->-r requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting idna<2.8,>=2.5 (from requests==2.20.0->-r requirements.txt (line 11))
#   Downloading https://files.pythonhosted.org/packages/4b/2a/0276479a4b3caeb8a8c1af2f8e4355746a97fab05a372e4a2c6a6b876165/idna-2.7-py2.py3-none-any.whl (58kB)
# Collecting protobuf3-to-dict>=0.1.5 (from sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/6b/55/522bb43539fed463275ee803d79851faaebe86d17e7e3dbc89870d0322b9/protobuf3-to-dict-0.1.5.tar.gz
# Collecting docker-compose>=1.23.0 (from sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/dd/e6/1521d1dfd9c0da1d1863b18e592d91c3df222e55f258b9876fa1e59bc4b5/docker_compose-1.24.1-py2.py3-none-any.whl (134kB)
# Collecting fabric>=2.0 (from sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/d7/cb/47feeb00dae857f0fbd1153a61e902e54ed77ccdc578b371a514a3959a19/fabric-2.5.0-py2.py3-none-any.whl (51kB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->-r requirements.txt (line 13))
#   Downloading https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting attrs (from packaging>=16.8->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/23/96/d828354fa2dbdf216eaa7b7de0db692f12c234f7ef888cc14980ef40d1d2/attrs-19.1.0-py2.py3-none-any.whl
# Collecting pyparsing>=2.0.2 (from packaging>=16.8->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/11/fa/0160cd525c62d7abd076a070ff02b2b94de589f1a9789774f17d7c54058e/pyparsing-2.4.2-py2.py3-none-any.whl (65kB)
# Collecting ipython>=4.0.0; python_version >= "3.3" (from ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/f6/c4/a79582814bdfe92bfca4d286a729304ffdf13f5135132cfcaea13cf1b2b3/ipython-7.7.0-py3-none-any.whl (774kB)
# Collecting widgetsnbextension~=3.5.0 (from ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/6c/7b/7ac231c20d2d33c445eaacf8a433f4e22c60677eb9776c7c5262d7ddee2d/widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2MB)
# Collecting traitlets>=4.3.1 (from ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/93/d6/abcb22de61d78e2fc3959c964628a5771e47e7cc60d53e9342e21ed6cc9a/traitlets-4.3.2-py2.py3-none-any.whl (74kB)
# Collecting nbformat>=4.2.0 (from ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/da/27/9a654d2b6cc1eaa517d1c5a4405166c7f6d72f04f6e7eea41855fe808a46/nbformat-4.4.0-py2.py3-none-any.whl (155kB)
# Collecting cffi>=1.0.0 (from xattr>=0.9.6->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/5f/bf/6aa1925384c23ffeb579e97a5569eb9abce41b6310b329352b8252cee1c3/cffi-1.12.3-cp36-cp36m-manylinux1_x86_64.whl (430kB)
# Collecting MarkupSafe>=0.23 (from Jinja2>=2.10.1->flask->-r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow->-r requirements.txt (line 5)) (41.2.0)
# Collecting markdown>=2.6.8 (from tensorboard<1.15.0,>=1.14.0->tensorflow->-r requirements.txt (line 5))
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
# Collecting jupyter-client>=4.1 (from qtconsole->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/af/4c/bf613864ae0644e2ac7d4a40bd209c40c8c71e3dc88d5f1d0aa92a68e716/jupyter_client-5.3.1-py2.py3-none-any.whl (91kB)
# Collecting pygments (from qtconsole->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/5c/73/1dfa428150e3ccb0fa3e68db406e5be48698f2a979ccbcec795f28f44048/Pygments-2.4.2-py2.py3-none-any.whl (883kB)
# Collecting ipython-genutils (from qtconsole->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting jupyter-core (from qtconsole->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/e6/25/6ffb0f6e57fa6ef5d2f814377133b361b42a6dd39105f4885a4f1666c2c3/jupyter_core-4.5.0-py2.py3-none-any.whl (78kB)
# Collecting Send2Trash (from notebook->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting prometheus-client (from notebook->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/b3/23/41a5a24b502d35a4ad50a5bb7202a5e1d9a0364d0c12f56db3dbf7aca76d/prometheus_client-0.7.1.tar.gz
# Collecting tornado>=5.0 (from notebook->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/30/78/2d2823598496127b21423baffaa186b668f73cd91887fcef78b6eade136b/tornado-6.0.3.tar.gz (482kB)
# Collecting terminado>=0.8.1 (from notebook->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/a7/56/80ea7fa66565fa75ae21ce0c16bc90067530e5d15e48854afcc86585a391/terminado-0.8.2-py2.py3-none-any.whl
# Collecting pyzmq>=17 (from notebook->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/75/89/6f0ea51ffa9c2c00c0ab0460f137b16a5ab5b47e3b060c5b1fc9ca425836/pyzmq-18.1.0-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
# Collecting prompt-toolkit<2.1.0,>=2.0.0 (from jupyter-console->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/f7/a7/9b1dd14ef45345f186ef69d175bdd2491c40ab1dfa4b2b3e4352df719ed7/prompt_toolkit-2.0.9-py3-none-any.whl (337kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz
# Collecting testpath (from nbconvert->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/be/a4/162f9ebb6489421fe46dcca2ae420369edfee4b563c668d93cb4605d12ba/testpath-0.4.2-py2.py3-none-any.whl (163kB)
# Collecting entrypoints>=0.2.2 (from nbconvert->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting mistune<2,>=0.8.1 (from nbconvert->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting defusedxml (from nbconvert->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting bleach (from nbconvert->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/ab/05/27e1466475e816d3001efb6e0a85a819be17411420494a1e602c36f8299d/bleach-3.1.0-py2.py3-none-any.whl (157kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib>=1.4.3->seaborn->-r requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/f8/a1/5742b56282449b1c0968197f63eae486eca2c35dcd334bab75ad524e0de1/kiwisolver-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (90kB)
# Collecting cycler>=0.10 (from matplotlib>=1.4.3->seaborn->-r requirements.txt (line 8))
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting pyasn1>=0.1.3 (from rsa<=3.5.0,>=3.1.2->awscli->-r requirements.txt (line 10))
#   Downloading https://files.pythonhosted.org/packages/6a/6e/209351ec34b7d7807342e2bb6ff8a96eef1fd5dcac13bdbadf065c2bb55c/pyasn1-0.4.6-py2.py3-none-any.whl (75kB)
# Collecting cached-property<2,>=1.2.0 (from docker-compose>=1.23.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/3b/86/85c1be2e8db9e13ef9a350aecd6dea292bd612fa288c2f40d035bb750ded/cached_property-1.5.1-py2.py3-none-any.whl
# Collecting docker[ssh]<4.0,>=3.7.0 (from docker-compose>=1.23.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/09/da/7cc7ecdcd01145e9924a8ccbe9c1baf3a362fc75d4cb150676eb5231ea60/docker-3.7.3-py2.py3-none-any.whl (134kB)
# Collecting texttable<0.10,>=0.9.0 (from docker-compose>=1.23.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/02/e1/2565e6b842de7945af0555167d33acfc8a615584ef7abd30d1eae00a4d80/texttable-0.9.1.tar.gz
# Collecting websocket-client<1.0,>=0.32.0 (from docker-compose>=1.23.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/29/19/44753eab1fdb50770ac69605527e8859468f3c0fd7dc5a76dd9c4dbd7906/websocket_client-0.56.0-py2.py3-none-any.whl (200kB)
# Collecting dockerpty<0.5,>=0.4.1 (from docker-compose>=1.23.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/8d/ee/e9ecce4c32204a6738e0a5d5883d3413794d7498fe8b06f44becc028d3ba/dockerpty-0.4.1.tar.gz
# Collecting jsonschema<3,>=2.5.1 (from docker-compose>=1.23.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/77/de/47e35a97b2b05c2fadbec67d44cfcdcd09b8086951b331d82de90d2912da/jsonschema-2.6.0-py2.py3-none-any.whl
# Collecting docopt<0.7,>=0.6.1 (from docker-compose>=1.23.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/a2/55/8f8cab2afd404cf578136ef2cc5dfb50baa1761b68c9da1fb1e4eed343c9/docopt-0.6.2.tar.gz
# Collecting invoke<2.0,>=1.3 (from fabric>=2.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/d9/7c/68e99f659749dbf3349ce72e2e9b581f644b8482121d92ab604145ad01ac/invoke-1.3.0-py3-none-any.whl (207kB)
# Collecting paramiko>=2.4 (from fabric>=2.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/4b/80/74dace9e48b0ef923633dfb5e48798f58a168e4734bca8ecfaf839ba051a/paramiko-2.6.0-py2.py3-none-any.whl (199kB)
# Collecting pexpect; sys_platform != "win32" (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/0e/3e/377007e3f36ec42f1b84ec322ee12141a9e10d808312e5738f52f80a232c/pexpect-4.7.0-py2.py3-none-any.whl (58kB)
# Collecting decorator (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/5f/88/0075e461560a1e750a0dcbf77f1d9de775028c37a19a346a6c565a257399/decorator-4.4.0-py2.py3-none-any.whl
# Collecting backcall (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/84/71/c8ca4f5bb1e08401b916c68003acf0a0655df935d74d93bf3f3364b310e0/backcall-0.1.0.tar.gz
# Collecting jedi>=0.10 (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/55/54/da994f359e4e7da4776a200e76dbc85ba5fc319eefc22e33d55296d95a1d/jedi-0.15.1-py2.py3-none-any.whl (1.0MB)
# Collecting pickleshare (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting pycparser (from cffi>=1.0.0->xattr>=0.9.6->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Collecting ptyprocess; os_name != "nt" (from terminado>=0.8.1->notebook->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting wcwidth (from prompt-toolkit<2.1.0,>=2.0.0->jupyter-console->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/7e/9f/526a6947247599b084ee5232e4f9190a38f398d7300d866af3ab571a5bfe/wcwidth-0.1.7-py2.py3-none-any.whl
# Collecting webencodings (from bleach->nbconvert->jupyter->-r requirements.txt (line 7))
#   Downloading https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting docker-pycreds>=0.4.0 (from docker[ssh]<4.0,>=3.7.0->docker-compose>=1.23.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting bcrypt>=3.1.3 (from paramiko>=2.4->fabric>=2.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/8b/1d/82826443777dd4a624e38a08957b975e75df859b381ae302cfd7a30783ed/bcrypt-3.1.7-cp34-abi3-manylinux1_x86_64.whl (56kB)
# Collecting pynacl>=1.0.1 (from paramiko>=2.4->fabric>=2.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
# Collecting cryptography>=2.5 (from paramiko>=2.4->fabric>=2.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/97/18/c6557f63a6abde34707196fb2cad1c6dc0dbff25a200d5044922496668a4/cryptography-2.7-cp34-abi3-manylinux1_x86_64.whl (2.3MB)
# Collecting parso>=0.5.0 (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=0.6.0->t4==0.1.4->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/a3/bd/bf4e5bd01d79906e5b945a7af033154da49fd2b0d5b5c705a21330323305/parso-0.5.1-py2.py3-none-any.whl (95kB)
# Collecting asn1crypto>=0.21.0 (from cryptography>=2.5->paramiko>=2.4->fabric>=2.0->sagemaker->-r requirements.txt (line 12))
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
# Building wheels for collected packages: sagemaker, t4, aws-requests-auth, future, humanize, xattr, wrapt, termcolor, absl-py, gast, pyyaml, protobuf3-to-dict, prometheus-client, tornado, pandocfilters, texttable, dockerpty, docopt, backcall, pycparser
#   Building wheel for sagemaker (setup.py): started
#   Building wheel for sagemaker (setup.py): finished with status 'done'
#   Created wheel for sagemaker: filename=sagemaker-1.38.4-py2.py3-none-any.whl size=286926 sha256=edd8c2f16ed78a752edbce97901bd140081c28c17f1e2df774972f38deca5f26
#   Stored in directory: /root/.cache/pip/wheels/92/b3/7a/edcbd93134b7c6a004931d6eb6663fc6ca70dcaedd2040cb46
#   Building wheel for t4 (setup.py): started
#   Building wheel for t4 (setup.py): finished with status 'done'
#   Created wheel for t4: filename=t4-0.1.4-cp36-none-any.whl size=73482 sha256=336cfd40952920f101418f3b4ad028f9ae1a680291ed797cc5fbd844fc42897e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hcfh9oae/wheels/b4/91/78/c594b014cb13ecd66bbfcd70f7ec3068642fbc559e4bd34c8b
#   Building wheel for aws-requests-auth (setup.py): started
#   Building wheel for aws-requests-auth (setup.py): finished with status 'done'
#   Created wheel for aws-requests-auth: filename=aws_requests_auth-0.4.2-cp36-none-any.whl size=6831 sha256=d582de055e620e1b1bbc400b0f38cb3e4b96ab96534ad7e21e7367e2d3072060
#   Stored in directory: /root/.cache/pip/wheels/3b/d7/e6/3bb2668c259b234ec78b7353f9063104dc449c1c89fc8e27f8
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.17.1-cp36-none-any.whl size=488730 sha256=c1909fed595a0228f6e672647faad641d1183d363cf39b9f82d9fa264f1816fc
#   Stored in directory: /root/.cache/pip/wheels/0c/61/d2/d6b7317325828fbb39ee6ad559dbe4664d0896da4721bf379e
#   Building wheel for humanize (setup.py): started
#   Building wheel for humanize (setup.py): finished with status 'done'
#   Created wheel for humanize: filename=humanize-0.5.1-cp36-none-any.whl size=17901 sha256=5461e1325eb53126a08e7a2a7966b743ef4d8b1d4bab2f246b381799bc687b59
#   Stored in directory: /root/.cache/pip/wheels/69/86/6c/f8b8593bc273ec4b0c653d3827f7482bb2001a2781a73b7f44
#   Building wheel for xattr (setup.py): started
#   Building wheel for xattr (setup.py): finished with status 'done'
#   Created wheel for xattr: filename=xattr-0.9.6-cp36-cp36m-linux_x86_64.whl size=30847 sha256=7458b705f07e0034e28b266210d15069e5c27f17a7ba7cfeac1fb612d3ad4c30
#   Stored in directory: /root/.cache/pip/wheels/8f/2d/20/eaf8403b661a46b93a1da3031f56eacb18eaae912d8a1683da
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.11.2-cp36-cp36m-linux_x86_64.whl size=75259 sha256=d425d2e8bd6f92f209788a3444ac4d787da8b6b974bc2120494dfc3dcc3ac82c
#   Stored in directory: /root/.cache/pip/wheels/d7/de/2e/efa132238792efb6459a96e85916ef8597fcb3d2ae51590dfd
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-cp36-none-any.whl size=4832 sha256=d5c5b71a618f5daaf591ab85213fba1a5c9c0d942e2598aff5b74b6495dc996c
#   Stored in directory: /root/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for absl-py (setup.py): started
#   Building wheel for absl-py (setup.py): finished with status 'done'
#   Created wheel for absl-py: filename=absl_py-0.8.0-cp36-none-any.whl size=120987 sha256=3494c8bf0169fd438fc7e1452b614711ca1a7df55cc72393491d26e3e8f25a84
#   Stored in directory: /root/.cache/pip/wheels/9a/1e/7a/456008eb5e47fd5de792c6139df6d5b3d5f71d51c6a0b94799
#   Building wheel for gast (setup.py): started
#   Building wheel for gast (setup.py): finished with status 'done'
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=90328935542019f90aa57b154382c254274679dec8aa49a455e00818ae71e471
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.1.2-cp36-cp36m-linux_x86_64.whl size=477672 sha256=de9d533134ba300e23de223d52ae4947351eb4af06fdffbaec68323c00b7e5d1
#   Stored in directory: /root/.cache/pip/wheels/d9/45/dd/65f0b38450c47cf7e5312883deb97d065e030c5cca0a365030
#   Building wheel for protobuf3-to-dict (setup.py): started
#   Building wheel for protobuf3-to-dict (setup.py): finished with status 'done'
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-cp36-none-any.whl size=4029 sha256=f1934085bb11852cf4533b70290f39cf6550a045023d4fa97c58afb03c2d33a3
#   Stored in directory: /root/.cache/pip/wheels/37/42/d8/1609d310cabebc2cf60eca038fa2b0c8503412963734a6fc31
#   Building wheel for prometheus-client (setup.py): started
#   Building wheel for prometheus-client (setup.py): finished with status 'done'
#   Created wheel for prometheus-client: filename=prometheus_client-0.7.1-cp36-none-any.whl size=41402 sha256=ae2569b09c1b590fa016532f62ac30de576070046dbadcd8da3a44f08c6b2774
#   Stored in directory: /root/.cache/pip/wheels/1c/54/34/fd47cd9b308826cc4292b54449c1899a30251ef3b506bc91ea
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Created wheel for tornado: filename=tornado-6.0.3-cp36-cp36m-linux_x86_64.whl size=423530 sha256=37947e420feb21b06df93fa78a457fd4df38ab54d024a03ee03dcf529ed31e8c
#   Stored in directory: /root/.cache/pip/wheels/84/bf/40/2f6ef700f48401ca40e5e3dd7d0e3c0a90e064897b7fe5fc08
#   Building wheel for pandocfilters (setup.py): started
#   Building wheel for pandocfilters (setup.py): finished with status 'done'
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.2-cp36-none-any.whl size=7856 sha256=f071cb54c706318f9a51d28f6cb2c0a9eedb5203ac9e05d92f124c791d29632a
#   Stored in directory: /root/.cache/pip/wheels/39/01/56/f1b08a6275acc59e846fa4c1e1b65dbc1919f20157d9e66c20
#   Building wheel for texttable (setup.py): started
#   Building wheel for texttable (setup.py): finished with status 'done'
#   Created wheel for texttable: filename=texttable-0.9.1-cp36-none-any.whl size=9971 sha256=4e5f355bbfa5040b85808acdb89cbce3d3853cbd6d0fca212eeb53839143ebba
#   Stored in directory: /root/.cache/pip/wheels/99/1e/2b/8452d3a48dad98632787556a0f2f90d56703b39cdf7d142dd1
#   Building wheel for dockerpty (setup.py): started
#   Building wheel for dockerpty (setup.py): finished with status 'done'
#   Created wheel for dockerpty: filename=dockerpty-0.4.1-cp36-none-any.whl size=16605 sha256=76e7c6e2b625761353889d8b42b7564c907f7e587c62da1acbf6859d39dcf2e6
#   Stored in directory: /root/.cache/pip/wheels/e5/1e/86/bd0a97a0907c6c654af654d5875d1d4383dd1f575f77cee4aa
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=a7e891888dabc4a2e5199d6bb591140cc5cf86a8484480c84e62fc130645cc07
#   Stored in directory: /root/.cache/pip/wheels/9b/04/dd/7daf4150b6d9b12949298737de9431a324d4b797ffd63f526e
#   Building wheel for backcall (setup.py): started
#   Building wheel for backcall (setup.py): finished with status 'done'
#   Created wheel for backcall: filename=backcall-0.1.0-cp36-none-any.whl size=10411 sha256=46beee64f9c5da9759e518a0e5a5d3205a264b511dff7ea6c0151dbf48ffdc2d
#   Stored in directory: /root/.cache/pip/wheels/98/b0/dd/29e28ff615af3dda4c67cab719dd51357597eabff926976b45
#   Building wheel for pycparser (setup.py): started
#   Building wheel for pycparser (setup.py): finished with status 'done'
#   Created wheel for pycparser: filename=pycparser-2.19-py2.py3-none-any.whl size=111029 sha256=3a42c94e89c5899f4edd801ae8cbd295ac6f597fd56afb2be3b4c10c2a078ea0
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built sagemaker t4 aws-requests-auth future humanize xattr wrapt termcolor absl-py gast pyyaml protobuf3-to-dict prometheus-client tornado pandocfilters texttable dockerpty docopt backcall pycparser
# ERROR: docker-compose 1.24.1 has requirement PyYAML<4.3,>=3.10, but you'll have pyyaml 5.1.2 which is incompatible.
# Installing collected packages: numpy, six, python-dateutil, pytz, pandas, click, itsdangerous, Werkzeug, MarkupSafe, Jinja2, flask, keras-preprocessing, h5py, keras-applications, protobuf, astor, wrapt, termcolor, google-pasta, tensorflow-estimator, grpcio, absl-py, markdown, tensorboard, gast, tensorflow, scipy, pyyaml, keras, ipython-genutils, decorator, traitlets, pyzmq, tornado, jupyter-core, jupyter-client, pygments, ptyprocess, pexpect, wcwidth, prompt-toolkit, backcall, parso, jedi, pickleshare, ipython, ipykernel, qtconsole, Send2Trash, prometheus-client, terminado, pandocfilters, jsonschema, nbformat, testpath, entrypoints, mistune, defusedxml, webencodings, bleach, nbconvert, notebook, widgetsnbextension, ipywidgets, jupyter-console, jupyter, kiwisolver, cycler, pyparsing, matplotlib, seaborn, joblib, scikit-learn, docutils, jmespath, urllib3, botocore, s3transfer, pyasn1, rsa, colorama, awscli, certifi, chardet, idna, requests, boto3, protobuf3-to-dict, cached-property, docker-pycreds, websocket-client, pycparser, cffi, bcrypt, pynacl, asn1crypto, cryptography, paramiko, docker, texttable, dockerpty, docopt, docker-compose, invoke, fabric, sagemaker, appdirs, aws-requests-auth, elasticsearch, future, jsonlines, attrs, packaging, pyarrow, ruamel.yaml, tqdm, humanize, xattr, t4
# Successfully installed Jinja2-2.10.1 MarkupSafe-1.1.1 Send2Trash-1.5.0 Werkzeug-0.15.5 absl-py-0.8.0 appdirs-1.4.3 asn1crypto-0.24.0 astor-0.8.0 attrs-19.1.0 aws-requests-auth-0.4.2 awscli-1.16.229 backcall-0.1.0 bcrypt-3.1.7 bleach-3.1.0 boto3-1.9.219 botocore-1.12.219 cached-property-1.5.1 certifi-2019.6.16 cffi-1.12.3 chardet-3.0.4 click-7.0 colorama-0.3.9 cryptography-2.7 cycler-0.10.0 decorator-4.4.0 defusedxml-0.6.0 docker-3.7.3 docker-compose-1.24.1 docker-pycreds-0.4.0 dockerpty-0.4.1 docopt-0.6.2 docutils-0.15.2 elasticsearch-6.3.1 entrypoints-0.3 fabric-2.5.0 flask-1.1.1 future-0.17.1 gast-0.2.2 google-pasta-0.1.7 grpcio-1.23.0 h5py-2.9.0 humanize-0.5.1 idna-2.7 invoke-1.3.0 ipykernel-5.1.2 ipython-7.7.0 ipython-genutils-0.2.0 ipywidgets-7.5.1 itsdangerous-1.1.0 jedi-0.15.1 jmespath-0.9.4 joblib-0.13.2 jsonlines-1.2.0 jsonschema-2.6.0 jupyter-1.0.0 jupyter-client-5.3.1 jupyter-console-6.0.0 jupyter-core-4.5.0 keras-2.2.5 keras-applications-1.0.8 keras-preprocessing-1.1.0 kiwisolver-1.1.0 markdown-3.1.1 matplotlib-3.1.1 mistune-0.8.4 nbconvert-5.6.0 nbformat-4.4.0 notebook-6.0.1 numpy-1.17.1 packaging-19.1 pandas-0.25.1 pandocfilters-1.4.2 paramiko-2.6.0 parso-0.5.1 pexpect-4.7.0 pickleshare-0.7.5 prometheus-client-0.7.1 prompt-toolkit-2.0.9 protobuf-3.9.1 protobuf3-to-dict-0.1.5 ptyprocess-0.6.0 pyarrow-0.14.1 pyasn1-0.4.6 pycparser-2.19 pygments-2.4.2 pynacl-1.3.0 pyparsing-2.4.2 python-dateutil-2.8.0 pytz-2019.2 pyyaml-5.1.2 pyzmq-18.1.0 qtconsole-4.5.4 requests-2.20.0 rsa-3.4.2 ruamel.yaml-0.15.70 s3transfer-0.2.1 sagemaker-1.38.4 scikit-learn-0.21.3 scipy-1.3.1 seaborn-0.9.0 six-1.12.0 t4-0.1.4 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 termcolor-1.1.0 terminado-0.8.2 testpath-0.4.2 texttable-0.9.1 tornado-6.0.3 tqdm-4.35.0 traitlets-4.3.2 urllib3-1.24.3 wcwidth-0.1.7 webencodings-0.5.1 websocket-client-0.56.0 widgetsnbextension-3.5.1 wrapt-1.11.2 xattr-0.9.6
# Removing intermediate container a15439a13430
#  ---> 4f722e8cab8b
# Step 6/14 : COPY "app.py" .
#  ---> 91167130675a
# Step 7/14 : COPY "run.sh" .
#  ---> 0ff4bdc222b8
# Step 8/14 : COPY "build.ipynb" .
#  ---> 03ca094c6bdf
# Step 9/14 : COPY "health-check-data.csv" .
#  ---> d90aeb963d29
# Step 10/14 : ENV FLASK_APP app.py
#  ---> Running in 515eb34d5006
# Removing intermediate container 515eb34d5006
#  ---> 249b68e33d24
# Step 11/14 : RUN ["chmod", "+x", "./run.sh"]
#  ---> Running in 3053915c8109
# Removing intermediate container 3053915c8109
#  ---> 2b217cc34e56
# Step 12/14 : EXPOSE 8080
#  ---> Running in eee4828a6f03
# Removing intermediate container eee4828a6f03
#  ---> c1d6b6e3bd17
# Step 13/14 : ENTRYPOINT ["./run.sh"]
#  ---> Running in 08fc75187e31
# Removing intermediate container 08fc75187e31
#  ---> 9928ec3f56e5
# Step 14/14 : CMD ["build"]
#  ---> Running in 18d20602eb7c
# Removing intermediate container 18d20602eb7c
#  ---> d8c2c3d195da
# Successfully built d8c2c3d195da
# Successfully tagged quiltdata/sagemaker-demo:latest
# DONE5
# The push refers to repository [645729154151.dkr.ecr.us-east-1.amazonaws.com/quiltdata/sagemaker-demo]
# 4f702ecd0ec9: Preparing
# a4094950ee63: Preparing
# 8bd73021c06c: Preparing
# 5d4de3d38c1c: Preparing
# 9cf650121bf2: Preparing
# 5488838d3203: Preparing
# 38d617c90fcb: Preparing
# d4cce4e134ba: Preparing
# 2fcfc4f651ee: Preparing
# 2ea1378e6b91: Preparing
# efb9a1092694: Preparing
# 1911313536c8: Preparing
# 6e302bbcacce: Preparing
# 97e8dd85db4e: Preparing
# 74e2ede3b29c: Preparing
# 6d5a64ea8f37: Preparing
# 660314270d76: Preparing
# 2ea1378e6b91: Waiting
# efb9a1092694: Waiting
# 74e2ede3b29c: Waiting
# 6d5a64ea8f37: Waiting
# 660314270d76: Waiting
# 1911313536c8: Waiting
# 6e302bbcacce: Waiting
# 97e8dd85db4e: Waiting
# 38d617c90fcb: Waiting
# d4cce4e134ba: Waiting
# 2fcfc4f651ee: Waiting
# 5488838d3203: Waiting
# 9cf650121bf2: Pushed
# a4094950ee63: Pushed
# 4f702ecd0ec9: Pushed
# 5d4de3d38c1c: Pushed
# 8bd73021c06c: Pushed
# d4cce4e134ba: Layer already exists
# 2fcfc4f651ee: Layer already exists
# 2ea1378e6b91: Layer already exists
# 1911313536c8: Layer already exists
# efb9a1092694: Layer already exists
# 6e302bbcacce: Layer already exists
# 97e8dd85db4e: Layer already exists
# 74e2ede3b29c: Layer already exists
# 6d5a64ea8f37: Layer already exists
# 660314270d76: Layer already exists
# 38d617c90fcb: Pushed
# 5488838d3203: Pushed
# latest: digest: sha256:73b214b060aab651e3876fe21477311b09b4a1d92ac3f3063fd480b23adfb69a size: 3884
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.

# %% [markdown]
# ## Training a model
#
# We use `sagemaker.estimator.Estimator` object to perform model training.
#
# Note that the `Estimator` object is parameterized with the image ARN (resource name), a role and session (passed down from the role executing this notebook instance), an instance and instance count, and an output path.
#
# The `output_path` is an interesting case. The default behavior of the various algorithms that SageMaker comes packaged with is to output a `*.tar.gz` model artifact into an S3 bucket, and this is a design pattern you are encouraged to use when using a custom image (as well) by e.g. the presence of this argument.
#
# Our image serializes model objects itself instead of relying on SageMaker to do it for us, rendering this argument useless. However it's not wise to omit it as SageMaker will automatically create a fresh run-dependent bucket for you if you do...
#
# **User note**: you should change `output_path` in the code cell that follows to any random S3 bucket that you own or that hasn't been claimed yet.

# %%
import boto3
import re

import os
import numpy as np
import pandas as pd

from sagemaker import get_execution_role
import sagemaker as sage

# %%
# this line of code require additional iam:GetRole permissions.
# role = get_execution_role()
# role = "arn:aws:iam::645729154151:role/krunal-sagemaker-full-access"
role = "arn:aws:iam::645729154151:role/service-role/AmazonSageMaker-ExecutionRole-20190828T170129"
sess = sage.Session()

account = sess.boto_session.client('sts').get_caller_identity()['Account']
region = sess.boto_session.region_name
image = '{}.dkr.ecr.{}.amazonaws.com/quiltdata/sagemaker-demo'.format(account, region)

# %% [markdown]
# Once the model is defined training is performed via `Esimator.fit`, mimicking the `scikit-learn` API.

# %%
clf = sage.estimator.Estimator(image,
                               role, 1, 'ml.c4.2xlarge',
                               output_path="s3://krunal-bdso-sagemaker/quilt/quilt_sagemaker_demo/model",
                               sagemaker_session=sess)

clf.fit()
# Out:
# 2019-08-29 21:33:32 Starting - Starting the training job...
# 2019-08-29 21:33:33 Starting - Launching requested ML instances......
# 2019-08-29 21:34:37 Starting - Preparing the instances for training...
# 2019-08-29 21:35:33 Downloading - Downloading input data
# 2019-08-29 21:35:33 Training - Downloading the training image........
# [NbConvertApp] Converting notebook build.ipynb to notebook
# [NbConvertApp] Executing notebook with kernel: python3
#
# 2019-08-29 21:36:37 Training - Training image download completed. Training in progress.2019-08-29 21:37:02.446973: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-08-29 21:37:02.476718: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2900060000 Hz
# 2019-08-29 21:37:02.477248: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5635788bea10 executing computations on platform Host. Devices:
# 2019-08-29 21:37:02.477276: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-08-29 21:37:02.673628: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
#
# 2019-08-29 21:37:28 Uploading - Uploading generated training model
# 2019-08-29 21:37:28 Completed - Training job completed
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/logging/__init__.py", line 1945, in shutdown
#     h.flush()
#   File "/usr/local/lib/python3.6/site-packages/absl/logging/__init__.py", line 891, in flush
#     self._current_handler.flush()
#   File "/usr/local/lib/python3.6/site-packages/absl/logging/__init__.py", line 785, in flush
#     self.stream.flush()
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/iostream.py", line 341, in flush
#     if self.pub_thread.thread.is_alive():
# AttributeError: 'NoneType' object has no attribute 'thread'
# [NbConvertApp] Writing 409137 bytes to build.ipynb
# Training seconds: 122
# Billable seconds: 122

# %% [markdown]
# Running this code block trains out model and deposits it in a `clf.tar.gz` file in an S3 bucket somewhere.

# %% [markdown]
# ## Deploying a model
#
# ### Deploy a fitted model as an endpoint

# %%
from sagemaker.predictor import csv_serializer
predictor = clf.deploy(1, 'ml.m4.xlarge', serializer=csv_serializer)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b87b4b39f3be> in <module>
#       1 from sagemaker.predictor import csv_serializer
# ----> 2 predictor = clf.deploy(1, 'ml.m4.xlarge', serializer=csv_serializer)
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/estimator.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, use_compiled_model, update_endpoint, wait, model_name, **kwargs)
#     543             update_endpoint=update_endpoint,
#     544             tags=self.tags,
# --> 545             wait=wait,
#     546         )
#     547
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/model.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, update_endpoint, tags, kms_key, wait)
#     448         else:
#     449             self.sagemaker_session.endpoint_from_production_variants(
# --> 450                 self.endpoint_name, [production_variant], tags, kms_key, wait
#     451             )
#     452
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in endpoint_from_production_variants(self, name, production_variants, tags, kms_key, wait)
#    1313
#    1314             self.sagemaker_client.create_endpoint_config(**config_options)
# -> 1315         return self.create_endpoint(endpoint_name=name, config_name=name, tags=tags, wait=wait)
#    1316
#    1317     def expand_role(self, role):
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in create_endpoint(self, endpoint_name, config_name, tags, wait)
#     951         )
#     952         if wait:
# --> 953             self.wait_for_endpoint(endpoint_name)
#     954         return endpoint_name
#     955
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in wait_for_endpoint(self, endpoint, poll)
#    1117             dict: Return value from the ``DescribeEndpoint`` API.
#    1118         """
# -> 1119         desc = _wait_until(lambda: _deploy_done(self.sagemaker_client, endpoint), poll)
#    1120         status = desc["EndpointStatus"]
#    1121
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in _wait_until(callable_fn, poll)
#    1825     result = callable_fn()
#    1826     while result is None:
# -> 1827         time.sleep(poll)
#    1828         result = callable_fn()
#    1829     return result
#
# KeyboardInterrupt:

# %%
# This fails because it lacks an authentication token.
# It might be possible to reconstruct the actual POST request being made.
# predictor.sagemaker_session.boto_session.get_credentials().token
# But the AWS docs are unclear about what name this hearder has.

# !curl -X "POST" -H "Content-Type: text/csv" -d @health-check-data.csv URI

# %%
X_test = pd.read_csv("./fashion-mnist_train.csv").head().iloc[:, 1:].values

# %%
sess.delete_endpoint(predictor.endpoint)

# %% [markdown]
# #### Deploy a pre-trained model artifact as an endpoint

# %%
from sagemaker import Model

# %%
model = Model(
    model_data='s3://krunal-bdso-sagemaker/quilt/quilt_sagemaker_demo/model/sagemaker-demo-2019-08-29-21-33-31-876/output/model.tar.gz',
    image=image,
    role=role,
    sagemaker_session=sess
)
# model.deploy(1, 'ml.c4.2xlarge')
predictor = model.deploy(1, 'ml.t2.medium')
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------*
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-8-e9160631689e> in <module>
#       6 )
#       7 # model.deploy(1, 'ml.c4.2xlarge')
# ----> 8 model.deploy(1, 'ml.t2.medium')
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/model.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, update_endpoint, tags, kms_key, wait)
#     448         else:
#     449             self.sagemaker_session.endpoint_from_production_variants(
# --> 450                 self.endpoint_name, [production_variant], tags, kms_key, wait
#     451             )
#     452
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in endpoint_from_production_variants(self, name, production_variants, tags, kms_key, wait)
#    1313
#    1314             self.sagemaker_client.create_endpoint_config(**config_options)
# -> 1315         return self.create_endpoint(endpoint_name=name, config_name=name, tags=tags, wait=wait)
#    1316
#    1317     def expand_role(self, role):
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in create_endpoint(self, endpoint_name, config_name, tags, wait)
#     951         )
#     952         if wait:
# --> 953             self.wait_for_endpoint(endpoint_name)
#     954         return endpoint_name
#     955
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in wait_for_endpoint(self, endpoint, poll)
#    1127                 ),
#    1128                 allowed_statuses=["InService"],
# -> 1129                 actual_status=status,
#    1130             )
#    1131         return desc
#
# UnexpectedStatusException: Error hosting endpoint sagemaker-demo-2019-08-29-22-52-20-738: Failed. Reason:  The primary container for production variant AllTraffic did not pass the ping health check. Please check CloudWatch logs for this endpoint..

# %%
predictor = sage.predictor.RealTimePredictor(
    'sagemaker-demo-2019-01-18-22-48-00-247', 
    sagemaker_session=sess, 
    content_type="text/csv")

# %%
inp = "\n".join([",".join(l) for l in X_test.astype('str').tolist()])

# %%
response = predictor.predict(inp)

# %%
response

# %%
import sagemaker as sage

# get and pass the auth role and image path, same as before
# this step is unchanged from the training script
role = "arn:aws:iam::645729154151:role/service-role/AmazonSageMaker-ExecutionRole-20190828T170129"
sess = sage.Session()
account = sess.boto_session.client('sts').get_caller_identity()['Account']
region = sess.boto_session.region_name
image = '{}.dkr.ecr.{}.amazonaws.com/quiltdata/sagemaker-demo'.format(account, region)

# create a new Model object
clf = Model(
    # insert model path below
    model_data='s3://krunal-bdso-sagemaker/quilt/quilt_sagemaker_demo/model/sagemaker-demo-2019-08-29-21-33-31-876/output/model.tar.gz',
    image=image,
    role=role,
    sagemaker_session=sess
)

# deploy it to an endpoint
# predictor = clf.deploy(1, 'ml.c4.2xlarge')
predictor = clf.deploy(1, 'ml.t2.medium')

# connect to the endpoint
predictor = sage.predictor.RealTimePredictor(
    'sagemaker-demo-[...]',  # insert model name here 
    sagemaker_session=sess, 
    content_type="text/csv"
)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1520e6bcf025> in <module>
#      20 # deploy it to an endpoint
#      21 # predictor = clf.deploy(1, 'ml.c4.2xlarge')
# ---> 22 predictor = clf.deploy(1, 'ml.t2.medium')
#      23
#      24 # connect to the endpoint
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/model.py in deploy(self, initial_instance_count, instance_type, accelerator_type, endpoint_name, update_endpoint, tags, kms_key, wait)
#     448         else:
#     449             self.sagemaker_session.endpoint_from_production_variants(
# --> 450                 self.endpoint_name, [production_variant], tags, kms_key, wait
#     451             )
#     452
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in endpoint_from_production_variants(self, name, production_variants, tags, kms_key, wait)
#    1313
#    1314             self.sagemaker_client.create_endpoint_config(**config_options)
# -> 1315         return self.create_endpoint(endpoint_name=name, config_name=name, tags=tags, wait=wait)
#    1316
#    1317     def expand_role(self, role):
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in create_endpoint(self, endpoint_name, config_name, tags, wait)
#     951         )
#     952         if wait:
# --> 953             self.wait_for_endpoint(endpoint_name)
#     954         return endpoint_name
#     955
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in wait_for_endpoint(self, endpoint, poll)
#    1117             dict: Return value from the ``DescribeEndpoint`` API.
#    1118         """
# -> 1119         desc = _wait_until(lambda: _deploy_done(self.sagemaker_client, endpoint), poll)
#    1120         status = desc["EndpointStatus"]
#    1121
#
# ~/Projects/BDSO-USCIS/aws-sagemaker/quilt-sagemaker-demo/.venv/lib/python3.6/site-packages/sagemaker/session.py in _wait_until(callable_fn, poll)
#    1825     result = callable_fn()
#    1826     while result is None:
# -> 1827         time.sleep(poll)
#    1828         result = callable_fn()
#    1829     return result
#
# KeyboardInterrupt:

# %% [markdown]
# #### Use a model artifact to perform a batch prediction run
#
# In order to perform a batch transform you must have a model.

# %%
transformer = sage.transformer.Transformer(
    base_transform_job_name='Batch-Transform',
    model_name='sagemaker-demo-2019-01-18-22-48-00-247',  # take this from a past training session
    instance_count=1,
    instance_type='ml.c4.xlarge',
    output_path='s3://quilt-example/quilt/quilt_sagemaker_demo/model',
    sagemaker_session=sess
)

# %%
# start the job
# note: this requires that the input data be in exactly the format expected by the model!
transformer.transform(
    's3://alpha-quilt-storage/aleksey/fashion_mnist/fashion-mnist_train.csv', 
    content_type='text/csv', 
    split_type='Line'
)

# wait until transform job is completed
transformer.wait()

# %%
import boto3
s3_client = boto3.resource('s3')

# %%
s3_client.download_file('s3://quilt-example/', 'quilt_sagemaker_demo/model/[...]')
